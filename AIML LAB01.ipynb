# %% [markdown]
# <a href="https://colab.research.google.com/github/2303a51687/AIML-2024-25/blob/main/AIML%20LAB01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LAB - 01

# %% [markdown]
# ASSSIGNMENT-1 :

# %% [markdown]
# Implement basic data structures of Numpy, Pandas, Matplotlib and Access Data from sources

# %% [markdown]
# 1.Lists
# 2.Arrays
# 3.Identify their type using type()
# 4.Perform mathematical operations on these datasets created - multiplication, division, poweroff
# 5.Combine text with Numpy fuction to generate a textual output - ”Addition of Two: array1 +array 2
# 6.Implement np.sin(), log(), log2(), np.exp())

# %%
import numpy as np
lst4=[4,5,6]
array4 = np.array(lst4)
array4
# Out:
# array([4, 5, 6])

# %%
type(lst4)
# Out:
# list

# %%
type(array4)
# Out:
# numpy.ndarray

# %% [markdown]
# MATHEMATICAL OPERATIONS :

# %%
list5=[6,5,4]
array5=np.array(list5)
array5
# Out:
# array([6, 5, 4])

# %%
print("array5 multiplied by array4: ",array4*array5)
print("array5 divided by array4: ",array5/array4)
print("array5 raised to the power of array4: ",array5**array4)
print(f" {array5} raised to the power of {array4}:,{array5**array4}")
# Out:
# array5 multiplied by array4:  [24 25 24]
# array5 divided by array4:  [1.5        1.         0.66666667]
# array5 raised to the power of array4:  [1296 3125 4096]
#  [6 5 4] raised to the power of [4 5 6]:,[1296 3125 4096]

# %%
print("Sine: ",np.sin(array4))

print("Natural logarithm: ",np.log(array4))
print("Base-10 logarithm: ",np.log10(array4))
print("Base-2 logarithm: ",np.log2(array4))
# Exponential
print("Exponential: ",np.exp(array4))
# Out:
# Sine:  [-0.7568025  -0.95892427 -0.2794155 ]
# Natural logarithm:  [1.38629436 1.60943791 1.79175947]
# Base-10 logarithm:  [0.60205999 0.69897    0.77815125]
# Base-2 logarithm:  [2.         2.32192809 2.5849625 ]
# Exponential:  [ 54.59815003 148.4131591  403.42879349]

# %%
print("Adding two numpy arrays {array4} and {array5} together:", array4+array5)
# Out:
# Adding two numpy arrays {array4} and {array5} together: [10 10 10]

# %%
print(f"Adding two numpy arrays {array4} and {array5} together: {array4+array5}")
# Out:
# Adding two numpy arrays [4 5 6] and [6 5 4] together: [10 10 10]

# %% [markdown]
# Part-02: Lab Task is to visualize the datasets or data using Matplotlib
# builtin function Graphs

# %% [markdown]
# Generate ScatterPlot :

# %%
people=['kiran','arun','vijay','varun']
age=[25,30,35,40,45]
height=[145,151,165,173]
weight=[45,55,65,75]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %% [markdown]
# Generate Bar Plot :

# %%
plt.bar(weight, height)
plt.title("Relationship between Weight and Height of Patients")
plt.ylabel("Height in Meters")
plt.xlabel("Weight of Patients in Kgs")
plt.show()

# %%
import matplotlib.pyplot as plt

people = ['Kiran', 'Arun', 'Vijay', 'Varun', 'Ravi']
ages = [25, 30, 35, 40, 45]
heights = [145, 151, 165, 173, 180]
weights = [45, 55, 65, 75, 85]

plt.figure(figsize=(8, 6))
plt.hist(heights, bins=5, color='lightgreen', edgecolor='black')
plt.title('Height Distribution')
plt.xlabel('Height (cm)')
plt.ylabel('Frequency')
plt.grid(True)

plt.show()
